# %%
import pandas as pd
df = pd.read_excel(r"GlenAllenhomes.xlsx")

# %%
df
# Out:
#     Size    Price  school rating                  Address  built year  \
# 0   4173   817500             18        2920 Ridgegate Pl        2007
# 1   1958   493000             17    10948 Forest Trace Ln        1994
# 2   3500   770000             22        5408 Woolshire Dr        2004
# 3   1454   405000             17       2904 Quail Walk Dr        1987
# 4   1008   310000              8          8001 Langley Dr        1954
# 5   1600   420000             17   5003 Meredith Woods Rd        1985
# 6   1296   384850             19   5003 Meredith Woods Rd        1983
# 7   2300   815714             14    11520 Pine Willow Cir        2024
# 8   1645   420000             17      5636 Lake Sharon Dr        1995
# 9   1800   421000             19            4709 Tameo Ct        1981
# 10  2300   815714             14    11520 Pine Willow Cir        2024
# 11  2660   741000             22       6013 Glen Abbey Dr        1995
# ...

# %%
df['Price'].values
# Out:
# array([ 817500,  493000,  770000,  405000,  310000,  420000,  384850,
#         815714,  420000,  421000,  815714,  741000, 1315000,  350000,
#         565000], dtype=int64)

# %%
df.head()
# Out:
#    Size   Price  school rating                Address  built year  \
# 0  4173  817500             18      2920 Ridgegate Pl        2007
# 1  1958  493000             17  10948 Forest Trace Ln        1994
# 2  3500  770000             22      5408 Woolshire Dr        2004
# 3  1454  405000             17     2904 Quail Walk Dr        1987
# 4  1008  310000              8        8001 Langley Dr        1954
#
#    Property type  selling year selling month
# 0  Single family          2025          July
# 1  Single family          2025          July
# 2  Single family          2025          July
# 3  Single family          2025          July
# 4  Single family          2025          July

# %%
df.iloc[0:-1,0:5]
# Out:
#     Size    Price  school rating                  Address  built year
# 0   4173   817500             18        2920 Ridgegate Pl        2007
# 1   1958   493000             17    10948 Forest Trace Ln        1994
# 2   3500   770000             22        5408 Woolshire Dr        2004
# 3   1454   405000             17       2904 Quail Walk Dr        1987
# 4   1008   310000              8          8001 Langley Dr        1954
# 5   1600   420000             17   5003 Meredith Woods Rd        1985
# 6   1296   384850             19   5003 Meredith Woods Rd        1983
# 7   2300   815714             14    11520 Pine Willow Cir        2024
# 8   1645   420000             17      5636 Lake Sharon Dr        1995
# 9   1800   421000             19            4709 Tameo Ct        1981
# 10  2300   815714             14    11520 Pine Willow Cir        2024
# 11  2660   741000             22       6013 Glen Abbey Dr        1995
# ...

# %%
x = df.iloc[:,0:1].values
x
# Out:
# array([[4173],
#        [1958],
#        [3500],
#        [1454],
#        [1008],
#        [1600],
#        [1296],
#        [2300],
#        [1645],
#        [1800],
#        [2300],
#        [2660],
#        [5722],
#        [1188],
#        [2422]], dtype=int64)

# %%
y = df.iloc[:,1].values
y
# Out:
# array([ 817500,  493000,  770000,  405000,  310000,  420000,  384850,
#         815714,  420000,  421000,  815714,  741000, 1315000,  350000,
#         565000], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x,y,test_size=.5, random_state= 0)
x_train.shape
# Out:
# (7, 1)

# %% [markdown]
# ## Price Prediction using Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#trial: Since we don't have a large dataset, let's make another model without train test
model1 = LinearRegression()
model1.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predic House Price Based on Size

# %%
model.predict([[2551],[2250]])
# Out:
# array([701244.98919465, 647339.74439582])

# %%
model1.predict([[2551],[2250]])
# Out:
# array([645789.00933388, 586029.76291756])

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([595046.28432519, 476490.56320615, 538991.99322208, 566750.5079856 ,
#        678142.74142373, 424913.45190361, 871198.73442421, 457149.1464677 ])

# %%
error = y_pred-y_test

# %%
error
# Out:
# array([102046.28432519,  91640.56320615, 118991.99322208, 145750.5079856 ,
#        113142.74142373, 114913.45190361, 101198.73442421, 107149.1464677 ])

# %% [markdown]
# ### HousePrice-size plot using test train method model

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, y_pred, color = 'blue' )

# %% [markdown]
# ### Since we don't have large dataset, lets make another plot using another model that doesn't use train_test_split method

# %%
yp = model1.predict(x)
plt.plot(x,yp,color = 'blue')
plt.scatter(x,y, color='red')

# %% [markdown]
# ### House Price prediction based on School Rating

# %%
x1 = df.iloc[:,2:3].values
x1
# Out:
# array([[18],
#        [17],
#        [22],
#        [17],
#        [ 8],
#        [17],
#        [19],
#        [14],
#        [17],
#        [19],
#        [14],
#        [22],
#        [22],
#        [19],
#        [19]], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x1,y)
# Out:
# LinearRegression()

# %%
yp1 = model.predict(x1)
yp1
# Out:
# array([614294.93247126, 585853.93462644, 728058.92385057, 585853.93462644,
#        329884.95402299, 585853.93462644, 642735.93031609, 500530.94109195,
#        585853.93462644, 642735.93031609, 500530.94109195, 728058.92385057,
#        728058.92385057, 642735.93031609, 642735.93031609])

# %%
import matplotlib.pyplot as plt
plt.scatter(x1,y, color = 'red')
plt.plot(x1,yp1,color = 'blue')
plt.xlabel('School rating')
plt.ylabel('House Price')
# Out:
# Text(0, 0.5, 'House Price')

# %% [markdown]
# ### House Price prediction based on built year

# %%
from sklearn.linear_model import LinearRegression
x2 = df.iloc[:,4:5].values
x2
# Out:
# array([[2007],
#        [1994],
#        [2004],
#        [1987],
#        [1954],
#        [1985],
#        [1983],
#        [2024],
#        [1995],
#        [1981],
#        [2024],
#        [1995],
#        [2014],
#        [1983],
#        [2004]], dtype=int64)

# %%
model = LinearRegression()
model.fit(x2,y)
# Out:
# LinearRegression()

# %%
yp2=model.predict(x2)
yp2
# Out:
# array([733027.09531553, 584657.68252882, 698788.00005706, 504766.46025905,
#        128136.41241584, 481940.3967534 , 459114.33324775, 927048.63511355,
#        596070.71428164, 436288.2697421 , 927048.63511355, 596070.71428164,
#        812918.3175853 , 459114.33324775, 698788.00005706])

# %%
x2= df['built year'].values
plt.scatter(x2,y, color = 'red')
plt.plot(x2,yp2,color = 'blue')
plt.xlabel('Built year')
plt.ylabel('House Price')
# Out:
# Text(0, 0.5, 'House Price')

# %% [markdown]
# ### r2 determines the performance of the test

# %% [markdown]
# ## Multiple Linear Regression

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\shampa\Courses\IBM Data Science\dataFor LinearRegression\GlenAllenhomes.xlsx")

# %%
df
# Out:
#     Size    Price  school rating                  Address  built year  \
# 0   4173   817500             18        2920 Ridgegate Pl        2007
# 1   1958   493000             17    10948 Forest Trace Ln        1994
# 2   3500   770000             22        5408 Woolshire Dr        2004
# 3   1454   405000             17       2904 Quail Walk Dr        1987
# 4   1008   310000              8          8001 Langley Dr        1954
# 5   1600   420000             17   5003 Meredith Woods Rd        1985
# 6   1296   384850             19   5003 Meredith Woods Rd        1983
# 7   2300   815714             14    11520 Pine Willow Cir        2024
# 8   1645   420000             17      5636 Lake Sharon Dr        1995
# 9   1800   421000             19            4709 Tameo Ct        1981
# 10  2300   815714             14    11520 Pine Willow Cir        2024
# 11  2660   741000             22       6013 Glen Abbey Dr        1995
# ...

# %% [markdown]
# ### Step 1: find out correlation coefficient for the variables

# %%
# dropped non-numeric variables to find out the correlation coefficient
df1 = df.drop(['Address','Property type','selling month'],axis = 1, inplace = False)
df1
# Out:
#     Size    Price  school rating  built year  selling year
# 0   4173   817500             18        2007          2025
# 1   1958   493000             17        1994          2025
# 2   3500   770000             22        2004          2025
# 3   1454   405000             17        1987          2025
# 4   1008   310000              8        1954          2025
# 5   1600   420000             17        1985          2025
# 6   1296   384850             19        1983          2025
# 7   2300   815714             14        2024          2025
# 8   1645   420000             17        1995          2025
# 9   1800   421000             19        1981          2025
# 10  2300   815714             14        2024          2025
# 11  2660   741000             22        1995          2025
# 12  5722  1315000             22        2014          2025
# 13  1188   350000             19        1983          2025
# 14  2422   565000             19        2004          2025

# %% [markdown]
# ### Find out the correlation of factors(size, school rating, built year, selling year) on house price

# %%
df1.corr()['Price']
# Out:
# Size             0.927238
# Price            1.000000
# school rating    0.379818
# built year       0.764836
# selling year          NaN
# Name: Price, dtype: float64

# %% [markdown]
# ### - Convert dataframe rows and columns into numpy  arrays
# ### - Select independent variables for x and dependent variable for y

# %%
import numpy
df_np = df1.to_numpy()
df_np
# Out:
# array([[   4173,  817500,      18,    2007,    2025],
#        [   1958,  493000,      17,    1994,    2025],
#        [   3500,  770000,      22,    2004,    2025],
#        [   1454,  405000,      17,    1987,    2025],
#        [   1008,  310000,       8,    1954,    2025],
#        [   1600,  420000,      17,    1985,    2025],
#        [   1296,  384850,      19,    1983,    2025],
#        [   2300,  815714,      14,    2024,    2025],
#        [   1645,  420000,      17,    1995,    2025],
#        [   1800,  421000,      19,    1981,    2025],
#        [   2300,  815714,      14,    2024,    2025],
#        [   2660,  741000,      22,    1995,    2025],
#        [   5722, 1315000,      22,    2014,    2025],
#        [   1188,  350000,      19,    1983,    2025],
#        [   2422,  565000,      19,    2004,    2025]], dtype=int64)

# %%
xm = df_np[:,[0,2,3]]
xm.shape[0]
# Out:
# 15

# %%
ym = df_np[:,1]
ym.shape[0]
# Out:
# 15

# %% [markdown]
# ### Step 4: Select model and train data

# %%
from sklearn.model_selection import train_test_split
xm_train, xm_test, ym_train, ym_test =train_test_split(xm,ym,test_size=.5, random_state= 0)

# %%
xm_train
# Out:
# array([[2300,   14, 2024],
#        [2300,   14, 2024],
#        [2660,   22, 1995],
#        [1454,   17, 1987],
#        [4173,   18, 2007],
#        [1600,   17, 1985],
#        [5722,   22, 2014]], dtype=int64)

# %%
ym_train
# Out:
# array([ 815714,  815714,  741000,  405000,  817500,  420000, 1315000],
#       dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xm_train,ym_train)
# Out:
# LinearRegression()

# %%
ym_predictions = model.predict(xm_train)

# %%
ym_predictions
# Out:
# array([ 810205.6626498 ,  810205.6626498 ,  776146.46266291,
#         395519.29149016,  898245.96671092,  382510.61466166,
#        1257094.33917476])

# %%
model.predict([[2500,   22, 1993]])
# Out:
# array([738558.36873569])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mean_absolute_error(ym_predictions, ym_train),mean_squared_error(ym_predictions,ym_train)
# Out:
# (33112.122678236236, 1809181705.8609233)

# %%
df2 = pd.DataFrame(xm_train)
df2
# Out:
#       0   1     2
# 0  2300  14  2024
# 1  2300  14  2024
# 2  2660  22  1995
# 3  1454  17  1987
# 4  4173  18  2007
# 5  1600  17  1985
# 6  5722  22  2014

# %%
predictions_df= pd.DataFrame({'Size': df2[0],
                             'School Rating': df2[1],
                             'Built Year':df2[2],
                             'Real Price':ym_train,
                            'predictions': ym_predictions})
predictions_df
# Out:
#    Size  School Rating  Built Year  Real Price   predictions
# 0  2300             14        2024      815714  8.102057e+05
# 1  2300             14        2024      815714  8.102057e+05
# 2  2660             22        1995      741000  7.761465e+05
# 3  1454             17        1987      405000  3.955193e+05
# 4  4173             18        2007      817500  8.982460e+05
# 5  1600             17        1985      420000  3.825106e+05
# 6  5722             22        2014     1315000  1.257094e+06

# %% [markdown]
# ## Theory review
# ### In statistics r2_score is known as R^2(coefficient of determination)¶
# ### R^2 = 1 - (sum of squared residuals,ssr/total sum of squares,tss)
# ### TSS=∑(actual y - mean y)^2 SSR=∑(actual y - predicted y)^2

# %%
from sklearn.metrics import r2_score
r2 = r2_score(ym_train,ym_predictions)
r2
# Out:
# 0.9773654747525928
